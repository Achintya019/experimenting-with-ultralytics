# %%
import os
import cv2
import yaml
from ultralytics import YOLO

# %%
dataset_yaml_path = '/home/achintya-trn0175/Intern/Experiment/expdataset.yaml'

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(data='/home/achintya-trn0175/Intern/Experiment/expdataset.yaml', epochs=50, imgsz=(480,640),batch=4)
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.9.19 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3894MiB)
# ...

# %%
expmodel_path=("/home/achintya-trn0175/Intern/Experiment/runs/detect/train2/weights/last.pt")
model = YOLO(expmodel_path)

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break
    results = model(frame)
    annotated_frame = results[0].plot()
    cv2.imshow("YOLOv8 Real-Time Object Detection", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@115.128] global /croot/opencv-suite_1676452025216/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# 0: 480x640 (no detections), 65.5ms
# Speed: 2.8ms preprocess, 65.5ms inference, 18.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 326.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
